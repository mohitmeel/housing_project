# %% [markdown]
# importing the libraries for the analysing of the dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %% [markdown]
# performing the EDA for better understanding of the dataset

# %%
df=pd.read_csv('housetrain.csv')
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL          NaN     4928   Pave   NaN      IR1
# 1     889          20       RL         95.0    15865   Pave   NaN      IR1
# 2     793          60       RL         92.0     9920   Pave   NaN      IR1
# 3     110          20       RL        105.0    11751   Pave   NaN      IR1
# 4     422          20       RL          NaN    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
# ...

# %%
df.head()
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  127         120       RL          NaN     4928   Pave   NaN      IR1
# 1  889          20       RL         95.0    15865   Pave   NaN      IR1
# 2  793          60       RL         92.0     9920   Pave   NaN      IR1
# 3  110          20       RL        105.0    11751   Pave   NaN      IR1
# 4  422          20       RL          NaN    16635   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      NPkVill       Norm
# 1         Lvl    AllPub    Inside       Mod        NAmes       Norm
# 2         Lvl    AllPub   CulDSac       Gtl      NoRidge       Norm
# 3         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 4         Lvl    AllPub       FR2       Gtl       NWAmes       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.tail()
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1163  289          20       RL          NaN     9819   Pave   NaN      IR1
# 1164  554          20       RL         67.0     8777   Pave   NaN      Reg
# 1165  196         160       RL         24.0     2280   Pave   NaN      Reg
# 1166   31          70  C (all)         50.0     8500   Pave  Pave      Reg
# 1167  617          60       RL          NaN     7861   Pave   NaN      IR1
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1163         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 1164         Lvl    AllPub    Inside       Gtl      Edwards      Feedr
# 1165         Lvl    AllPub       FR2       Gtl      NPkVill       Norm
# 1166         Lvl    AllPub    Inside       Gtl       IDOTRR      Feedr
# 1167         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.shape
# Out:
# (1168, 81)

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1168 entries, 0 to 1167
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1168 non-null   int64
#  1   MSSubClass     1168 non-null   int64
#  2   MSZoning       1168 non-null   object
#  3   LotFrontage    954 non-null    float64
#  4   LotArea        1168 non-null   int64
#  5   Street         1168 non-null   object
#  6   Alley          77 non-null     object
#  7   LotShape       1168 non-null   object
#  8   LandContour    1168 non-null   object
#  9   Utilities      1168 non-null   object
#  10  LotConfig      1168 non-null   object
#  11  LandSlope      1168 non-null   object
#  12  Neighborhood   1168 non-null   object
#  13  Condition1     1168 non-null   object
#  14  Condition2     1168 non-null   object
#  15  BldgType       1168 non-null   object
#  16  HouseStyle     1168 non-null   object
# ...

# %% [markdown]
# finding out that is there null values present in the columns of the dataset

# %%
df.isnull()
# Out:
#          Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     False       False     False         True    False   False   True
# 1     False       False     False        False    False   False   True
# 2     False       False     False        False    False   False   True
# 3     False       False     False        False    False   False   True
# 4     False       False     False         True    False   False   True
# ...     ...         ...       ...          ...      ...     ...    ...
# 1163  False       False     False         True    False   False   True
# 1164  False       False     False        False    False   False   True
# 1165  False       False     False        False    False   False   True
# 1166  False       False     False        False    False   False  False
# 1167  False       False     False         True    False   False   True
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      214
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# the null values present in the columns of datatype numeric is to be replaced by its mean value

# %%
for i in df.columns:
    if df[i].dtypes=='float64':
        np.mean(df[i])
        df[i]=df[i].fillna(np.mean(df[i]))

# %%
df
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     127         120       RL     70.98847     4928   Pave   NaN      IR1
# 1     889          20       RL     95.00000    15865   Pave   NaN      IR1
# 2     793          60       RL     92.00000     9920   Pave   NaN      IR1
# 3     110          20       RL    105.00000    11751   Pave   NaN      IR1
# 4     422          20       RL     70.98847    16635   Pave   NaN      IR1
# ...   ...         ...      ...          ...      ...    ...   ...      ...
# 1163  289          20       RL     70.98847     9819   Pave   NaN      IR1
# 1164  554          20       RL     67.00000     8777   Pave   NaN      Reg
# 1165  196         160       RL     24.00000     2280   Pave   NaN      Reg
# 1166   31          70  C (all)     50.00000     8500   Pave  Pave      Reg
# 1167  617          60       RL     70.98847     7861   Pave   NaN      IR1
#
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %% [markdown]
# the columns of data type is object is going to be converted in the numeric data type for maintaining the accuarcy by label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     127         120         3     70.98847     4928       1      2
# 1     889          20         3     95.00000    15865       1      2
# 2     793          60         3     92.00000     9920       1      2
# 3     110          20         3    105.00000    11751       1      2
# 4     422          20         3     70.98847    16635       1      2
# ...   ...         ...       ...          ...      ...     ...    ...
# 1163  289          20         3     70.98847     9819       1      2
# 1164  554          20         3     67.00000     8777       1      2
# 1165  196         160         3     24.00000     2280       1      2
# 1166   31          70         0     50.00000     8500       1      1
# 1167  617          60         3     70.98847     7861       1      2
#
#       LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
df.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 81, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# now seeing the correlation betwwen the coulmns and the features with the target columns and also visualizing it with heatmap

# %%
dfcor=df.corr()
dfcor
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.004259  0.009307    -0.005969 -0.029212
# MSSubClass     0.004259    1.000000  0.007478    -0.336681 -0.124151
# MSZoning       0.009307    0.007478  1.000000    -0.069661 -0.023328
# LotFrontage   -0.005969   -0.336681 -0.069661     1.000000  0.299452
# LotArea       -0.029212   -0.124151 -0.023328     0.299452  1.000000
# ...                 ...         ...       ...          ...       ...
# MoSold         0.023479   -0.016015 -0.051646     0.022517  0.015141
# YrSold        -0.008853   -0.038595 -0.004964    -0.003885 -0.035399
# SaleType       0.024384    0.035050  0.079854    -0.035356  0.005421
# SaleCondition -0.014726   -0.028981  0.004501     0.065091  0.034236
# SalePrice     -0.023897   -0.060775 -0.133221     0.323779  0.249499
#
#                  Street     Alley  LotShape  LandContour  Utilities  \
# Id             0.003613  0.008284  0.022978    -0.020245        NaN
# ...

# %%
dfcor.SalePrice
# Out:
# Id              -0.023897
# MSSubClass      -0.060775
# MSZoning        -0.133221
# LotFrontage      0.323779
# LotArea          0.249499
#                    ...
# MoSold           0.072764
# YrSold          -0.045508
# SaleType        -0.050851
# SaleCondition    0.217687
# SalePrice        1.000000
# Name: SalePrice, Length: 81, dtype: float64

# %%
plt.figure(figsize=(25,22))
sns.heatmap(dfcor,cmap='Blues',linewidths=2.5,linecolor='black')
# Out:
# <AxesSubplot:>

# %%
df.drop('Utilities',axis=1,inplace=True)

# %%
dfcorr=df.corr()
dfcorr
# Out:
#                      Id  MSSubClass  MSZoning  LotFrontage   LotArea  \
# Id             1.000000    0.004259  0.009307    -0.005969 -0.029212
# MSSubClass     0.004259    1.000000  0.007478    -0.336681 -0.124151
# MSZoning       0.009307    0.007478  1.000000    -0.069661 -0.023328
# LotFrontage   -0.005969   -0.336681 -0.069661     1.000000  0.299452
# LotArea       -0.029212   -0.124151 -0.023328     0.299452  1.000000
# ...                 ...         ...       ...          ...       ...
# MoSold         0.023479   -0.016015 -0.051646     0.022517  0.015141
# YrSold        -0.008853   -0.038595 -0.004964    -0.003885 -0.035399
# SaleType       0.024384    0.035050  0.079854    -0.035356  0.005421
# SaleCondition -0.014726   -0.028981  0.004501     0.065091  0.034236
# SalePrice     -0.023897   -0.060775 -0.133221     0.323779  0.249499
#
#                  Street     Alley  LotShape  LandContour  LotConfig  \
# Id             0.003613  0.008284  0.022978    -0.020245   0.053927
# ...

# %%
plt.figure(figsize=(25,22))
sns.heatmap(dfcorr,cmap='Blues',linewidths=2.5,linecolor='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# the statistical view of the dataset

# %%
df.describe()
# Out:
#                 Id   MSSubClass     MSZoning  LotFrontage        LotArea  \
# count  1168.000000  1168.000000  1168.000000  1168.000000    1168.000000
# mean    724.136130    56.767979     3.013699    70.988470   10484.749144
# std     416.159877    41.940650     0.633120    22.437056    8957.442311
# min       1.000000    20.000000     0.000000    21.000000    1300.000000
# 25%     360.500000    20.000000     3.000000    60.000000    7621.500000
# 50%     714.500000    50.000000     3.000000    70.988470    9522.500000
# 75%    1079.500000    70.000000     3.000000    79.250000   11515.500000
# max    1460.000000   190.000000     4.000000   313.000000  164660.000000
#
#             Street        Alley     LotShape  LandContour    LotConfig  \
# count  1168.000000  1168.000000  1168.000000  1168.000000  1168.000000
# mean      0.996575     1.898973     1.938356     2.773973     3.004281
# std       0.058445     0.401453     1.412262     0.710027     1.642667
# ...

# %% [markdown]
# now checking the outliers present in the dataset

# %%
df.plot(kind='box',subplots=True,layout=(8,10),figsize=(22,20))
# Out:
# Id                  AxesSubplot(0.125,0.799681;0.065678x0.0803191)
# MSSubClass       AxesSubplot(0.203814,0.799681;0.065678x0.0803191)
# MSZoning         AxesSubplot(0.282627,0.799681;0.065678x0.0803191)
# LotFrontage      AxesSubplot(0.361441,0.799681;0.065678x0.0803191)
# LotArea          AxesSubplot(0.440254,0.799681;0.065678x0.0803191)
#                                        ...
# MoSold              AxesSubplot(0.519068,0.125;0.065678x0.0803191)
# YrSold              AxesSubplot(0.597881,0.125;0.065678x0.0803191)
# SaleType            AxesSubplot(0.676695,0.125;0.065678x0.0803191)
# SaleCondition       AxesSubplot(0.755508,0.125;0.065678x0.0803191)
# SalePrice           AxesSubplot(0.834322,0.125;0.065678x0.0803191)
# Length: 80, dtype: object

# %% [markdown]
# removing the outliers in the dataset

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# 0     1.435487    1.508301  0.021646     0.000000  0.620616  0.058621
# 1     0.396325    0.877042  0.021646     1.070631  0.600903  0.058621
# 2     0.165545    0.077095  0.021646     0.936867  0.063075  0.058621
# 3     1.476354    0.877042  0.021646     1.516514  0.141424  0.058621
# 4     0.726321    0.877042  0.021646     0.000000  0.686902  0.058621
# ...        ...         ...       ...          ...       ...       ...
# 1163  1.046046    0.877042  0.021646     0.000000  0.074355  0.058621
# 1164  0.408999    0.877042  0.021646     0.177839  0.190733  0.058621
# 1165  1.269614    2.462438  0.021646     2.095132  0.916362  0.058621
# 1166  1.666266    0.315629  4.762117     0.935838  0.221670  0.058621
# 1167  0.257550    0.077095  0.021646     0.000000  0.293038  0.058621
#
#          Alley  LotShape  LandContour  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   1,    1,    1, ..., 1166, 1166, 1166], dtype=int64), array([10, 21, 35, ..., 40, 63, 64], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0      127         120         3     70.98847     4928       1      2
# 2      793          60         3     92.00000     9920       1      2
# 5     1197          60         3     58.00000    14054       1      2
# 6      561          20         3     70.98847    11341       1      2
# 11     833          60         3     44.00000     9548       1      2
# ...    ...         ...       ...          ...      ...     ...    ...
# 1158   673          20         3     70.98847    11250       1      2
# 1161  1301          60         3     70.98847    10762       1      2
# 1163   289          20         3     70.98847     9819       1      2
# 1165   196         160         3     24.00000     2280       1      2
# 1167   617          60         3     70.98847     7861       1      2
#
#       LotShape  LandContour  LotConfig  LandSlope  Neighborhood  Condition1  \
# ...

# %%
df_new.shape
# Out:
# (447, 80)

# %%
data_loss=((1168-447)/1168)*100
data_loss
# Out:
# 61.72945205479452

# %% [markdown]
# as the data loss percentage after removing outliers present in the dataset is 61%
# which shows more than the half of the dataset is removed,
# it means that the accuracy of data is not maintained and also the dataset is becoming biased
# so the the outliers present will not be removed

# %% [markdown]
# now the checking the skewness in the columns

# %%
df.skew()
# Out:
# Id                0.026526
# MSSubClass        1.422019
# MSZoning         -1.796785
# LotFrontage       2.710383
# LotArea          10.659285
#                    ...
# MoSold            0.220979
# YrSold            0.115765
# SaleType         -3.660513
# SaleCondition    -2.671829
# SalePrice         1.953878
# Length: 80, dtype: float64

# %%
df.plot(kind='kde',subplots=True,layout=(8,10),figsize=(22,20))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %%
df.plot(kind='hist',subplots=True,layout=(8,10),figsize=(22,20))
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
# ...

# %% [markdown]
# removing the skewness present by power transform

# %%
from sklearn.preprocessing import power_transform

# %%
x=df.drop('SalePrice',axis=1)
x
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     127         120         3     70.98847     4928       1      2
# 1     889          20         3     95.00000    15865       1      2
# 2     793          60         3     92.00000     9920       1      2
# 3     110          20         3    105.00000    11751       1      2
# 4     422          20         3     70.98847    16635       1      2
# ...   ...         ...       ...          ...      ...     ...    ...
# 1163  289          20         3     70.98847     9819       1      2
# 1164  554          20         3     67.00000     8777       1      2
# 1165  196         160         3     24.00000     2280       1      2
# 1166   31          70         0     50.00000     8500       1      1
# 1167  617          60         3     70.98847     7861       1      2
#
#       LotShape  LandContour  LotConfig  LandSlope  Neighborhood  Condition1  \
# ...

# %%
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)
x
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# 0    -1.544968    1.370435 -0.162456     0.093658 -1.213954  0.058621
# 1     0.461941   -1.167999 -0.162456     1.117135  1.100521  0.058621
# 2     0.254221    0.490047 -0.162456     0.998803  0.158048  0.058621
# 3    -1.610857   -1.167999 -0.162456     1.495566  0.496002  0.058621
# 4    -0.635571   -1.167999 -0.162456     0.093658  1.196626  0.058621
# ...        ...         ...       ...          ...       ...       ...
# 1163 -1.008279   -1.167999 -0.162456     0.093658  0.137703  0.058621
# 1164 -0.299331   -1.167999 -0.162456    -0.096350 -0.084786  0.058621
# 1165 -1.300337    1.700798 -0.162456    -2.852857 -2.681835  0.058621
# 1166 -1.975680    0.696557 -2.926464    -0.996296 -0.148203  0.058621
# 1167 -0.147481    0.490047 -0.162456     0.093658 -0.302416  0.058621
#
#          Alley  LotShape  LandContour  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
x.skew()
# Out:
# Id              -0.268486
# MSSubClass       0.064007
# MSZoning         0.233113
# LotFrontage      0.161368
# LotArea          0.032509
#                    ...
# MiscVal          4.991071
# MoSold          -0.035838
# YrSold           0.112893
# SaleType        -2.067563
# SaleCondition   -0.353292
# Length: 79, dtype: float64

# %%
x_new=power_transform(x)
x=pd.DataFrame(x_new,columns=x.columns)
x
# Out:
#             Id  MSSubClass  MSZoning  LotFrontage   LotArea    Street  \
# 0    -1.459317    1.371579 -0.120168     0.090938 -1.205254  0.058621
# 1     0.401799   -1.167403 -0.120168     1.118357  1.106837  0.058621
# 2     0.176555    0.488977 -0.120168     0.999300  0.145474  0.058621
# 3    -1.512299   -1.167403 -0.120168     1.499477  0.487459  0.058621
# 4    -0.688692   -1.167403 -0.120168     0.090938  1.206047  0.058621
# ...        ...         ...       ...          ...       ...       ...
# 1163 -1.014455   -1.167403 -0.120168     0.090938  0.125006  0.058621
# 1164 -0.379181   -1.167403 -0.120168    -0.099057 -0.097784  0.058621
# 1165 -1.259642    1.703139 -0.120168    -2.835500 -2.610344  0.058621
# 1166 -1.800152    0.695857 -3.266015    -0.995719 -0.160936  0.058621
# 1167 -0.233266    0.488977 -0.120168     0.090938 -0.313918  0.058621
#
#          Alley  LotShape  LandContour  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
x.skew()
# Out:
# Id              -0.048846
# MSSubClass       0.066692
# MSZoning        -0.312102
# LotFrontage      0.206096
# LotArea          0.257288
#                    ...
# MiscVal          4.991071
# MoSold          -0.022300
# YrSold           0.033866
# SaleType        -2.022608
# SaleCondition    0.076174
# Length: 79, dtype: float64

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       128000
# 1       268000
# 2       269790
# 3       190000
# 4       215000
#          ...
# 1163    122000
# 1164    108000
# 1165    148500
# 1166     40000
# 1167    183200
# Name: SalePrice, Length: 1168, dtype: int64

# %%
x.shape
# Out:
# (1168, 79)

# %%
y.shape
# Out:
# (1168,)

# %% [markdown]
# scaling the data by using standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
x1=ss.fit_transform(x)
x1
# Out:
# array([[-1.45931668e+00,  1.37157880e+00, -1.20167948e-01, ...,
#         -5.85607320e-01,  4.11301488e-01, -2.31861554e-03],
#        [ 4.01799105e-01, -1.16740269e+00, -1.20167948e-01, ...,
#         -5.85607320e-01,  4.11301488e-01, -2.31861554e-03],
#        [ 1.76554913e-01,  4.88977414e-01, -1.20167948e-01, ...,
#         -5.85607320e-01,  4.11301488e-01, -2.31861554e-03],
#        ...,
#        [-1.25964168e+00,  1.70313903e+00, -1.20167948e-01, ...,
#          9.06009340e-01,  4.11301488e-01, -2.31861554e-03],
#        [-1.80015167e+00,  6.95856689e-01, -3.26601531e+00, ...,
#          1.82432331e-01,  4.11301488e-01, -2.31861554e-03],
#        [-2.33265738e-01,  4.88977414e-01, -1.20167948e-01, ...,
#         -1.39172499e+00,  4.11301488e-01, -2.31861554e-03]])

# %%
x=pd.DataFrame(x1)
x
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.459317  1.371579 -0.120168  0.090938 -1.205254  0.058621  0.265664
# 1     0.401799 -1.167403 -0.120168  1.118357  1.106837  0.058621  0.265664
# 2     0.176555  0.488977 -0.120168  0.999300  0.145474  0.058621  0.265664
# 3    -1.512299 -1.167403 -0.120168  1.499477  0.487459  0.058621  0.265664
# 4    -0.688692 -1.167403 -0.120168  0.090938  1.206047  0.058621  0.265664
# ...        ...       ...       ...       ...       ...       ...       ...
# 1163 -1.014455 -1.167403 -0.120168  0.090938  0.125006  0.058621  0.265664
# 1164 -0.379181 -1.167403 -0.120168 -0.099057 -0.097784  0.058621  0.265664
# 1165 -1.259642  1.703139 -0.120168 -2.835500 -2.610344  0.058621  0.265664
# 1166 -1.800152  0.695857 -3.266015 -0.995719 -0.160936  0.058621 -3.764151
# 1167 -0.233266  0.488977 -0.120168  0.090938 -0.313918  0.058621  0.265664
#
# ...

# %% [markdown]
# using the another file for input variables but the output variable will be same of the above data

# %%
df1=pd.read_csv('housetest.csv')
df1
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL         86.0    14157   Pave   NaN      IR1
# 1    1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2     929          20       RL          NaN    11838   Pave   NaN      Reg
# 3    1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4    1227          60       RL         86.0    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
# ...

# %%
df1.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   337          20       RL         86.0    14157   Pave   NaN      IR1
# 1  1018         120       RL          NaN     5814   Pave   NaN      IR1
# 2   929          20       RL          NaN    11838   Pave   NaN      Reg
# 3  1148          70       RL         75.0    12000   Pave   NaN      Reg
# 4  1227          60       RL         86.0    14598   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         HLS    AllPub    Corner       Gtl      StoneBr       Norm
# 1         Lvl    AllPub   CulDSac       Gtl      StoneBr       Norm
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 4         Lvl    AllPub   CulDSac       Gtl      Somerst      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df1.tail()
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 287    83          20       RL         78.0    10206   Pave   NaN      Reg
# 288  1048          20       RL         57.0     9245   Pave   NaN      IR2
# 289    17          20       RL          NaN    11241   Pave   NaN      IR1
# 290   523          50       RM         50.0     5000   Pave   NaN      Reg
# 291  1379         160       RM         21.0     1953   Pave   NaN      Reg
#
#     LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 287         Lvl    AllPub    Inside       Gtl      Somerst       Norm
# 288         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 289         Lvl    AllPub   CulDSac       Gtl        NAmes       Norm
# 290         Lvl    AllPub    Corner       Gtl      BrkSide      Feedr
# 291         Lvl    AllPub    Inside       Gtl       BrDale       Norm
#
#     Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df1.shape
# Out:
# (292, 80)

# %%
df1.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df1.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# Length: 80, dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 292 entries, 0 to 291
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             292 non-null    int64
#  1   MSSubClass     292 non-null    int64
#  2   MSZoning       292 non-null    object
#  3   LotFrontage    247 non-null    float64
#  4   LotArea        292 non-null    int64
#  5   Street         292 non-null    object
#  6   Alley          14 non-null     object
#  7   LotShape       292 non-null    object
#  8   LandContour    292 non-null    object
#  9   Utilities      292 non-null    object
#  10  LotConfig      292 non-null    object
#  11  LandSlope      292 non-null    object
#  12  Neighborhood   292 non-null    object
#  13  Condition1     292 non-null    object
#  14  Condition2     292 non-null    object
#  15  BldgType       292 non-null    object
#  16  HouseStyle     292 non-null    object
# ...

# %%
df1.isnull()
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0    False       False     False        False    False   False   True
# 1    False       False     False         True    False   False   True
# 2    False       False     False         True    False   False   True
# 3    False       False     False        False    False   False   True
# 4    False       False     False        False    False   False   True
# ..     ...         ...       ...          ...      ...     ...    ...
# 287  False       False     False        False    False   False   True
# 288  False       False     False        False    False   False   True
# 289  False       False     False         True    False   False   True
# 290  False       False     False        False    False   False   True
# 291  False       False     False        False    False   False   True
#
#      LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
df1.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage      45
# LotArea           0
#                  ..
# MiscVal           0
# MoSold            0
# YrSold            0
# SaleType          0
# SaleCondition     0
# Length: 80, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
for i in df1.columns:
    if df1[i].dtypes=='float64':
        np.mean(df1[i])
        df1[i]=df1[i].fillna(np.mean(df1[i]))

# %%
df1
# Out:
#        Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     337          20       RL    86.000000    14157   Pave   NaN      IR1
# 1    1018         120       RL    66.425101     5814   Pave   NaN      IR1
# 2     929          20       RL    66.425101    11838   Pave   NaN      Reg
# 3    1148          70       RL    75.000000    12000   Pave   NaN      Reg
# 4    1227          60       RL    86.000000    14598   Pave   NaN      IR1
# ..    ...         ...      ...          ...      ...    ...   ...      ...
# 287    83          20       RL    78.000000    10206   Pave   NaN      Reg
# 288  1048          20       RL    57.000000     9245   Pave   NaN      IR2
# 289    17          20       RL    66.425101    11241   Pave   NaN      IR1
# 290   523          50       RM    50.000000     5000   Pave   NaN      Reg
# 291  1379         160       RM    21.000000     1953   Pave   NaN      Reg
#
# ...

# %%
df1.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 80, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in df1.columns:
    if df1[i].dtypes=='object':
        df1[i]=le.fit_transform(df1[i].values.reshape(-1,1))

# %%
df1.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 80, dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
df1.drop('PoolQC',axis=1,inplace=True)

# %%
df1
# Out:
#        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  \
# 0     337          20         2    86.000000    14157       1      2
# 1    1018         120         2    66.425101     5814       1      2
# 2     929          20         2    66.425101    11838       1      2
# 3    1148          70         2    75.000000    12000       1      2
# 4    1227          60         2    86.000000    14598       1      2
# ..    ...         ...       ...          ...      ...     ...    ...
# 287    83          20         2    78.000000    10206       1      2
# 288  1048          20         2    57.000000     9245       1      2
# 289    17          20         2    66.425101    11241       1      2
# 290   523          50         3    50.000000     5000       1      2
# 291  1379         160         3    21.000000     1953       1      2
#
#      LotShape  LandContour  Utilities  LotConfig  LandSlope  Neighborhood  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
x1=ss.fit_transform(df1)
x1
# Out:
# array([[-0.94827766, -0.85605433, -0.28700579, ..., -0.65090813,
#          0.23029007,  0.14865423],
#        [ 0.59312021,  1.43198105, -0.28700579, ...,  0.86355541,
#         -6.49418003, -3.32390858],
#        [ 0.39167468, -0.85605433, -0.28700579, ...,  0.86355541,
#          0.23029007,  0.14865423],
#        ...,
#        [-1.67257621, -0.85605433, -0.28700579, ...,  1.62078718,
#          0.23029007,  0.14865423],
#        [-0.52727912, -0.16964372,  1.80813647, ..., -1.4081399 ,
#          0.23029007,  0.14865423],
#        [ 1.41021953,  2.3471952 ,  1.80813647, ..., -1.4081399 ,
#          0.23029007,  0.14865423]])

# %%
x=pd.DataFrame(x1)
x
# Out:
#            0         1         2         3         4         5        6   \
# 0   -0.948278 -0.856054 -0.287006  0.981605  0.263894  0.083045  0.21501
# 1    0.593120  1.431981 -0.287006  0.000000 -0.363030  0.083045  0.21501
# 2    0.391675 -0.856054 -0.287006  0.000000  0.089636  0.083045  0.21501
# 3    0.887367  0.287963 -0.287006  0.429998  0.101809  0.083045  0.21501
# 4    1.066178  0.059160 -0.287006  0.981605  0.297033  0.083045  0.21501
# ..        ...       ...       ...       ...       ...       ...      ...
# 287 -1.523190 -0.856054 -0.287006  0.580436 -0.032999  0.083045  0.21501
# 288  0.661023 -0.856054 -0.287006 -0.472632 -0.105212  0.083045  0.21501
# 289 -1.672576 -0.856054 -0.287006  0.000000  0.044775  0.083045  0.21501
# 290 -0.527279 -0.169644  1.808136 -0.823655 -0.424197  0.083045  0.21501
# 291  1.410220  2.347195  1.808136 -2.277892 -0.653160  0.083045  0.21501
#
#            7         8         9         10        11        12        13  \
# ...

# %%
x
# Out:
#            0         1         2         3         4         5        6   \
# 0   -0.948278 -0.856054 -0.287006  0.981605  0.263894  0.083045  0.21501
# 1    0.593120  1.431981 -0.287006  0.000000 -0.363030  0.083045  0.21501
# 2    0.391675 -0.856054 -0.287006  0.000000  0.089636  0.083045  0.21501
# 3    0.887367  0.287963 -0.287006  0.429998  0.101809  0.083045  0.21501
# 4    1.066178  0.059160 -0.287006  0.981605  0.297033  0.083045  0.21501
# ..        ...       ...       ...       ...       ...       ...      ...
# 287 -1.523190 -0.856054 -0.287006  0.580436 -0.032999  0.083045  0.21501
# 288  0.661023 -0.856054 -0.287006 -0.472632 -0.105212  0.083045  0.21501
# 289 -1.672576 -0.856054 -0.287006  0.000000  0.044775  0.083045  0.21501
# 290 -0.527279 -0.169644  1.808136 -0.823655 -0.424197  0.083045  0.21501
# 291  1.410220  2.347195  1.808136 -2.277892 -0.653160  0.083045  0.21501
#
#            7         8         9         10        11        12        13  \
# ...

# %%
y=df.iloc[0:292,-1]
y
# Out:
# 0      128000
# 1      268000
# 2      269790
# 3      190000
# 4      215000
#         ...
# 287    178000
# 288    131000
# 289    145000
# 290     97500
# 291    307000
# Name: SalePrice, Length: 292, dtype: int64

# %%
x.shape
# Out:
# (292, 79)

# %%
y.shape
# Out:
# (292,)

# %% [markdown]
# splitting the data for training and testing and importing the important libraries for calling models to make machine learn

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=455,test_size=.30)

# %%
x_train.shape
# Out:
# (204, 79)

# %%
x_test.shape
# Out:
# (88, 79)

# %%
y_test.shape
# Out:
# (88,)

# %%
y_train.shape
# Out:
# (204,)

# %% [markdown]
# finding out the best random state

# %%
maxsc=0
maxrs=0
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    lm=LinearRegression()
    lm.fit(x_train,y_train)
    predlm=lm.predict(x_test)
    score=lm.score(x_train,y_train)
    if score>maxsc:
        maxsc=score
        maxrs=i
print(maxsc)
print(maxrs)
# Out:
# 0.5377202967069
# 455

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
predlm=lm.predict(x_test)
print('mean absolute error:',mean_absolute_error(y_test,predlm))
print('mean squared error:',mean_squared_error(y_test,predlm))
print(lm.score(x_train,y_train))
print(r2_score(y_test,predlm))
# Out:
# mean absolute error: 1179464439766652.0
# mean squared error: 4.415134818198984e+31
# 0.5377202967069
# -5.202033611219805e+21

# %%
ls=Lasso(alpha=.0001)
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
print(ls.coef_)
# Out:
# 0.35764382576565557
# [ 15642.49388056  -3540.69843155   4816.95464465 -11537.10786494
#    8917.88454392   7782.60930038   2322.29365846   -988.44285698
#   -3936.66336986    -81.27999521  -4884.29410601   8508.34692429
#    2216.87304136  -1508.13548418  -2628.28716212  -1566.33246753
#    6573.57724926 -17066.77831873 -13497.6569916   23917.72896711
#    4908.75444175   -303.66733046 -31310.18897972 -25946.11960881
#   27764.28903701 -22833.84536784  -3086.15677182  -1450.45644625
#    5028.74787929 -10249.59199479  17687.45736292   2233.78258868
#    4933.12054183  20514.05947924   3552.58375631 -19608.20713182
#  -14462.74217434 -28702.563813   -14210.56568555  21632.73943135
#    4139.22063267  15779.95911422  13351.36649685  12067.69507109
#   -1129.13571224 -21169.25132548   3661.78687063  -2883.94352449
#   -1203.73308574 -13164.42871724 -25222.47502056  -3284.52937395
#  -10650.07324801 -17222.4541419   30488.63306359  -6529.75149552
# ...

# %%
plt.figure(figsize=(7,5))
plt.bar(x.columns,ls.coef_)
# Out:
# <BarContainer object of 79 artists>

# %%
rg=Ridge(alpha=.0001)
rg.fit(x_train,y_train)
print(rg.score(x_train,y_train))
print(rg.coef_)
# Out:
# 0.35764382576189346
# [ 15642.45062303  -3540.65302184   4816.96909196 -11537.13393724
#    8917.86073427   7782.65491225   2322.27185764   -988.45070409
#   -3936.65362626    -81.25198812  -4884.26283629   8508.37680073
#    2216.87637869  -1508.13867657  -2628.29402621  -1566.38127158
#    6573.5157437  -17066.68544001 -13497.64198484  23917.6364858
#    4908.74590577   -303.62928387 -31310.00602996 -25945.93037861
#   27764.11935614 -22833.80751309  -3086.14387604  -1450.520693
#    5028.71315806 -10249.54519412  17687.40621082   2233.80895142
#    4933.12563914  20514.00302855   8522.23438989 -19608.0263077
#  -12698.62579459 -23946.98411118 -19122.27062925  21632.64128191
#    4139.2127528   15779.90467996  13351.31332712  11272.94407731
#   -2047.85736777 -21251.85572374   4775.22377184  -2883.89787341
#   -1203.74996335 -13164.42216819 -25222.37092313  -3284.46365843
#  -10650.00369063 -17222.3700444   30488.46983516  -6529.72413083
# ...

# %%
plt.figure(figsize=(7,5))
plt.bar(x.columns,rg.coef_)
# Out:
# <BarContainer object of 79 artists>

# %%
kernel_list=['linear','poly','rbf']
for i in kernel_list:
    svr=SVR(kernel=i)
    svr.fit(x_train,y_train)
    print(svr.score(x_train,y_train))
# Out:
# -0.06327621407271367
# -0.061644771907928275
# -0.06173108185417897

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predrfr=rfr.predict(x_test)
print('predicted house_price',predrfr)
print('actual house_price',y_test)
print('score',rfr.score(x_train,y_train))
# Out:
# predicted house_price [177343.33 157773.06 153687.6  200829.5  193674.14 155487.78 156833.
#  187171.79 263185.54 227433.23 140302.82 171039.13 173115.05 231862.62
#  170774.65 148174.26 200384.96 177234.41 196192.24 164829.18 157485.5
#  205872.38 243438.47 178138.02 179125.34 173727.24 169148.5  140185.06
#  177417.91 181872.84 268687.02 233137.86 206501.42 209126.71 177521.48
#  190512.46 194629.08 185462.15 186891.68 162765.74 246239.77 164078.1
#  157856.85 218198.76 206573.64 116068.   216639.26 182097.42 197906.
#  150932.68 166280.   222349.14 197842.64 184330.41 157105.18 192434.1
#  189663.74 182532.68 151371.16 149449.32 237067.8  176012.54 170411.6
#  148590.66 160900.62 154036.7  140202.02 153258.4  177734.52 199175.
#  229710.43 264291.06 172522.78 171313.74 176091.37 169424.38 262735.54
#  171490.64 211257.81 241954.73 162651.5  209378.16 233800.24 156265.76
#  160795.74 182794.88 180561.5  222064.32]
# actual house_price 217    208900
# 153    174000
# 278    119900
# ...

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predrfr,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('actual house_price',fontsize=14)
plt.ylabel('predicted house_price',fontsize=14)
plt.title('random forest regressor',fontsize=18)
plt.show()

# %%
houseprice=pd.DataFrame({'predicted house_price':predrfr,'actual house_price':y_test})
houseprice
# Out:
#      predicted house_price  actual house_price
# 149              143895.77              109500
# 42               172809.47              144152
# 55               270772.89              230000
# 214              187656.77              171000
# 238              201745.42               98000
# ..                     ...                 ...
# 15               200691.87              165000
# 91               215115.77              287000
# 188              151121.72              154000
# 69               188133.42              148000
# 70               178017.78              173000
#
# [88 rows x 2 columns]

# %%
pd.set_option('display.max_rows',None)
houseprice
# Out:
#      predicted house_price  actual house_price
# 149              143895.77              109500
# 42               172809.47              144152
# 55               270772.89              230000
# 214              187656.77              171000
# 238              201745.42               98000
# 271              185303.41               87000
# 284              179832.84              176000
# 189              174080.17              141000
# 129              144111.12              110000
# 180              157483.32               55000
# 254              164922.06              275000
# 85               245874.06              102000
# 81               208366.73              127000
# 104              178215.44              335000
# 41               179179.89              132000
# 73               228086.24              174900
# 150              133996.10              162000
# 220              187361.06              137000
# 209              155288.17              135750
# ...

# %%
import pickle
filename='housing_project.pkl'
pickle.dump(rfr,open(filename,'wb'))

# %% [markdown]
# the best model is random forest classifier as its score is 84.

# %% [markdown]
# completed
